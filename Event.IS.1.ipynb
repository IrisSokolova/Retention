# %% [markdown]
# В игре Plants & Gardens каждый месяц проводятся тематические события, ограниченные по времени.
# В них игроки могут получить уникальные предметы для сада и персонажей, дополнительные монеты или бонусы. Для получения награды требуется пройти ряд уровней за определенное время.
# С помощью каких метрик можно оценить результаты последнего прошедшего события?
#
# Предположим, в другом событии мы усложнили механику событий так, что при каждой неудачной попытке выполнения уровня игрок будет откатываться на несколько уровней назад. Изменится ли набор метрик оценки результата? Если да, то как?

# %% [markdown]
# 1. Оценить воронку конверсии пользователей от одного события к другому, анализируем в чему привели шаги, каким образом меняется количество пользователей от шага к шагу.
# Исследуя воронку можно понять как изменение сложности меняет интерес пользователей к игре.
#
# 2. Retention и Rolling Retention. Необходимо выделить несколько когорт (событие а,  событие в, событие с) сравнивать retention этих групп. Кривая 'выживания' и heatmap помогут понять становится ли retention личше или хуже после произошедшего события в игре.
#
#
#
#
# ![retention.png](attachment:retention.png)
#
#
#
#
#
# 3. A/B тест, сравнить между собой день события и предыдущий день.
# Верно ли, что ретеншен дня события статисически значимо лучше или хуже предыдущего дня.
# Можно применить z-test и установить alfa level 0.05

# %% [markdown]
# Каждая метрика характеризует определенное состояние активного пользователя игры:
#
# ### Метрики продукта / Состояние и поведение пользователся
#
# ##### Active users  (DAU, MAU)
# Оценивает позитивные эмоции, любопытство. Это тот показатель, который имеет смысл отслеживать в реальном времени.
# ##### Количество сессий
# производительность и эффективность.
# ##### Продолжительность сессий (ASL)
# состояние потока, игры пр
# ###### Retention  и Rolling Retention
# кривая научения, усвоенный материал.
# Сравнить различные группы пользователей, друг с другом, разделив их по определенному признаку.
# ##### Sticky Factor
# регулярность - входы в течение месяца
# ##### Виральность (K-factor, Invites Sent)
# привлечение других пользователей.
# ##### Социальность
# запросы на дополнительную информацию, любопытство, интерес к продукту.

# %% [markdown]
# Например:
# Если после изменения в игре увеличилась продолжительность сессий, это может говорить о том, что релиз был удачный,
# и пользователей получилось заставить подольше оставаться в продукте. И если это так, и заинтересованность пользователей увеличилась, то это значит что и финансовые метрики скорее всего должны возрасти,
# а вместе с ними и retention

# %% [markdown]
# Основные метрики которым сделует уделять внимание:
#
# Вовлечение (Involment). Присутствие пользователя. Измеряется количеством посещений, временем сессий и т.д.
#
# Взаимодействие (Interaction). Активность пользователя. Измеряется CTR, on-line действиями.
#
# Близость (Intimacy). Привлечение, или отвращение пользователя. Измеряется рейтингами удовлетворенности, анализом настроений в блогах, комментариями, опросами.
#
# Влияние (Influence). Вероятность того, что пользователь станет промоутером. Измеряется репостами, количеством приглашений, рассылаемых друзьям.
